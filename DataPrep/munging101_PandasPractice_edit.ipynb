# %%
import json
import datetime
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Public data
# - https://data.sfgov.org
# - http://catalog.data.gov/dataset
# - https://aws.amazon.com/datasets  (Huge datasets)
#
# # For scraping
# - http://www.basketball-reference.com
# - http://www.baseball-reference.com
# - http://www.football-reference.com
#
# # Datasets on the web
# - http://static.reddit.com/RedditShortDemoSurvey-1.csv (Reddit user survey)
# - https://extxfer.sfdph.org/food/

# %% [markdown]
# # Reading a web csv into pandas

# %%
#from the web
#https://data.sfgov.org/Health-and-Social-Services/Restaurant-Scores/stya-26eb
resturants = pd.read_csv('source_data/SFFoodProgram_Complete_Data/businesses_plus.csv')
inspections = pd.read_csv('source_data/SFFoodProgram_Complete_Data/inspections_plus.csv')
violations = pd.read_csv('source_data/SFFoodProgram_Complete_Data/violations_plus.csv')

# %%
violations.head()
# Out:
#    business_id      date  ViolationTypeID  risk_category  \
# 0           10  20140729           103144       Low Risk
# 1           10  20140729           103129  Moderate Risk
# 2           10  20140114           103154       Low Risk
# 3           10  20140114           103145       Low Risk
# 4           10  20140114           103119  Moderate Risk
#
#                                          description
# 0   Unapproved or unmaintained equipment or utensils
# 1            Insufficient hot water or running water
# 2       Unclean or degraded floors walls or ceilings
# 3   Improper storage of equipment utensils or linens
# 4  Inadequate and inaccessible handwashing facili...

# %%
tmp = pd.merge(resturants, inspections, how='inner', on='business_id')
tmp.head(1)
# Out:
#    business_id              name        address           city postal_code  \
# 0           10  Tiramisu Kitchen  033 Belden Pl  San Francisco       94104
#
#     latitude   longitude  phone_number TaxCode  business_certificate  \
# 0  37.791116 -122.403816           NaN     H24                779059
#
#   application_date    owner_name owner_address     owner_city owner_state  \
# 0              NaN  Tiramisu LLC  33 Belden St  San Francisco          CA
#
#   owner_zip  Score      date                   type
# 0     94104    NaN  20140807  Reinspection/Followup

# %%
#Class exercise - merge the violations table into the dataframe we just created - call it rest_data
#Hint, example the tmp and the violations table - a proper join is more than one column
rest_data = pd.merge(tmp, violations, how='inner', on=['business_id', 'date'])
rest_data.head(10)
# Out:
#    business_id                  name            address           city  \
# 0           10      Tiramisu Kitchen      033 Belden Pl  San Francisco
# 1           10      Tiramisu Kitchen      033 Belden Pl  San Francisco
# 2           10      Tiramisu Kitchen      033 Belden Pl  San Francisco
# 3           10      Tiramisu Kitchen      033 Belden Pl  San Francisco
# 4           10      Tiramisu Kitchen      033 Belden Pl  San Francisco
# 5           10      Tiramisu Kitchen      033 Belden Pl  San Francisco
# 6           10      Tiramisu Kitchen      033 Belden Pl  San Francisco
# 7           17  GEORGE'S COFFEE SHOP  2200 OAKDALE Ave            S.F.
# 8           17  GEORGE'S COFFEE SHOP  2200 OAKDALE Ave            S.F.
# 9           17  GEORGE'S COFFEE SHOP  2200 OAKDALE Ave            S.F.
#
#   postal_code   latitude   longitude  phone_number TaxCode  \
# 0       94104  37.791116 -122.403816           NaN     H24
# 1       94104  37.791116 -122.403816           NaN     H24
# 2       94104  37.791116 -122.403816           NaN     H24
# 3       94104  37.791116 -122.403816           NaN     H24
# 4       94104  37.791116 -122.403816           NaN     H24
# 5       94104  37.791116 -122.403816           NaN     H24
# 6       94104  37.791116 -122.403816           NaN     H24
# 7       94124  37.741086 -122.401737   14155531470     H24
# 8       94124  37.741086 -122.401737   14155531470     H24
# 9       94124  37.741086 -122.401737   14155531470     H24
#
#    business_certificate                        ...                          \
# 0                779059                        ...
# 1                779059                        ...
# 2                779059                        ...
# 3                779059                        ...
# 4                779059                        ...
# 5                779059                        ...
# 6                779059                        ...
# 7                 78443                        ...
# 8                 78443                        ...
# 9                 78443                        ...
#
#          owner_address     owner_city owner_state owner_zip Score      date  \
# 0         33 Belden St  San Francisco          CA     94104    94  20140729
# 1         33 Belden St  San Francisco          CA     94104    94  20140729
# 2         33 Belden St  San Francisco          CA     94104    92  20140114
# 3         33 Belden St  San Francisco          CA     94104    92  20140114
# 4         33 Belden St  San Francisco          CA     94104    92  20140114
# 5         33 Belden St  San Francisco          CA     94104    98  20121114
# 6         33 Belden St  San Francisco          CA     94104    98  20120403
# 7  648 MACARTHUR DRIVE      DALY CITY          CA     94015    94  20140312
# 8  648 MACARTHUR DRIVE      DALY CITY          CA     94015    94  20140312
# 9  648 MACARTHUR DRIVE      DALY CITY          CA     94015    94  20140312
#
#                     type  ViolationTypeID  risk_category  \
# 0  Routine - Unscheduled           103144       Low Risk
# 1  Routine - Unscheduled           103129  Moderate Risk
# 2  Routine - Unscheduled           103154       Low Risk
# 3  Routine - Unscheduled           103145       Low Risk
# 4  Routine - Unscheduled           103119  Moderate Risk
# 5  Routine - Unscheduled           103154       Low Risk
# 6  Routine - Unscheduled           103154       Low Risk
# 7  Routine - Unscheduled           103154       Low Risk
# 8  Routine - Unscheduled           103144       Low Risk
# 9  Routine - Unscheduled           103142       Low Risk
#
#                                          description
# 0   Unapproved or unmaintained equipment or utensils
# 1            Insufficient hot water or running water
# 2       Unclean or degraded floors walls or ceilings
# 3   Improper storage of equipment utensils or linens
# 4  Inadequate and inaccessible handwashing facili...
# 5       Unclean or degraded floors walls or ceilings
# 6       Unclean or degraded floors walls or ceilings
# 7       Unclean or degraded floors walls or ceilings
# 8   Unapproved or unmaintained equipment or utensils
# 9                   Unclean nonfood contact surfaces
#
# [10 rows x 22 columns]

# %% [markdown]
# ## Clean the dataset

# %%
rest_data.describe()
# Out:
#         business_id      latitude     longitude  phone_number  \
# count  45589.000000  45589.000000  45589.000000  1.045900e+04
# mean   27851.383426     37.649976   -122.021032  1.415547e+10
# std    27402.967774      2.170560      7.034320  8.826141e+05
# min       10.000000      0.000000   -122.510896  1.415020e+10
# 25%     3052.000000     37.760813   -122.436847  1.415537e+10
# 50%    13814.000000     37.782033   -122.418286  1.415558e+10
# 75%    62176.000000     37.792455   -122.407313  1.415578e+10
# max    71915.000000     37.875937      0.000000  1.415973e+10
#
#        business_certificate         Score             date  ViolationTypeID
# count          38958.000000  41112.000000     45589.000000     45589.000000
# mean          423744.315930     85.294367  20132108.930268    103134.545636
# std           204795.622843      8.875510      8684.444326        16.735429
# min              671.000000     46.000000  20120319.000000    103101.000000
# 25%           343738.000000     80.000000  20121203.000000    103120.000000
# 50%           404697.000000     87.000000  20130819.000000    103139.000000
# 75%           458698.000000     92.000000  20140421.000000    103149.000000
# max          1008789.000000    100.000000  20151230.000000    103178.000000

# %% [markdown]
# ### Longitude / Latitude

# %%
#Class: Drop resturants where the longitude latitidue is undefined (nan)
#testing for null - pd.isnull or np.isnan
rest_data = rest_data[~(pd.isnull(rest_data.longitude))]
rest_data = rest_data[~(pd.isnull(rest_data.latitude))]

# %% [markdown]
# ### Date column fixing

# %%
#Just a fyi - make dates the correct datatype
print "Date columns datatype: {}".format(rest_data.date.dtypes)

def convert_date(row):
    try:
        date = datetime.datetime.strptime(row['date'], "%Y%M%d")
    except:
        date = ''
    return date

#I would like dates to be treated as dates
rest_data['date'] = rest_data['date'].astype('str')

rest_data['inspection_date'] = rest_data.apply(convert_date, axis='columns')


print "Date columns datatype: {}".format(rest_data.inspection_date.dtypes)
# Out:
# Date columns datatype: int64
# Date columns datatype: datetime64[ns]

# %% [markdown]
# ### Zip code cleaning

# %%
rest_data.postal_code.unique()
# Out:
# array(['94104', '94124', '94109', '94103', '94110', '94122', '94115',
#        '94131', '94111', '94133', '94117', '94107', '94108', '94102',
#        '94132', '94105', '94134', '94116', '94121', '94118', '94112',
#        '94127', '94123', '94114', '94513', '94158', '94140', '94013',
#        '94130', '94120', '94143', '94609', '94101'], dtype=object)

# %%
#Class exercise - drop the records with a nan zip code
nan_zips = pd.isnull(rest_data.postal_code)
rest_data = rest_data[~(nan_zips)]

# %%
#Class exercise - drop records with weird zip codes - i.e. 941033148
#Hint - dataframe.column.isin - is a useful method
weird_zips = ['941033148','CA','00000','CA  94523', '92672']
print "There are {} records with weird zip codes".format(rest_data.postal_code[(rest_data.postal_code.isin(weird_zips))].count())
rest_data = rest_data[~(rest_data.postal_code.isin(weird_zips))]
# Out:
# There are 0 records with weird zip codes

# %%
rest_data.postal_code.unique()
# Out:
# array(['94104', '94124', '94109', '94103', '94110', '94122', '94115',
#        '94131', '94111', '94133', '94117', '94107', '94108', '94102',
#        '94132', '94105', '94134', '94116', '94121', '94118', '94112',
#        '94127', '94123', '94114', '94513', '94158', '94140', '94013',
#        '94130', '94120', '94143', '94609', '94101'], dtype=object)

# %% [markdown]
# ## Remove zipcode with less than 100 resturants

# %%
rest_data.postal_code.value_counts()
# Out:
# 94133    5015
# 94110    4258
# 94103    3860
# 94109    3653
# 94102    3099
# 94122    2568
# 94108    2287
# 94115    1846
# 94111    1817
# 94118    1800
# 94107    1765
# 94123    1753
# 94121    1540
# 94114    1461
# 94112    1364
# 94117    1137
# 94105     895
# 94116     864
# 94124     736
# 94104     703
# 94127     664
# 94132     644
# 94134     580
# 94131     382
# 94143      38
# 94609      20
# 94120      10
# 94101       8
# 94513       8
# 94158       8
# 94130       5
# 94013       5
# 94140       4
# dtype: int64

# %%
#[x for x in zip_mean_counts[('Score','len')] > 100]

# %%
#Unpack this step by step
zip_mean_counts = rest_data[['postal_code','Score']].groupby('postal_code').aggregate([np.mean, len]).sort([('Score','mean')])
qualifying_zips = np.array([x for x in zip_mean_counts[('Score','len')] > 100])
zip_code_list = zip_mean_counts[qualifying_zips].index
zip_code_list
# Out:
# Index([u'94133', u'94108', u'94122', u'94127', u'94116', u'94103', u'94102', u'94121', u'94109', u'94134', u'94111', u'94110', u'94124', u'94118', u'94123', u'94105', u'94117', u'94115', u'94114', u'94104', u'94112', u'94131', u'94107', u'94132'], dtype='object')

# %% [markdown]
# ## Explore the dataset

# %%
#What is the range of scores?
rest_data['Score'].describe()
# Out:
# count    40363.000000
# mean        85.272304
# std          8.882450
# min         46.000000
# 25%         80.000000
# 50%         87.000000
# 75%         92.000000
# max        100.000000
# Name: Score, dtype: float64

# %%
#Class exercise - plot a density plot or historgram showing the distribution of scores

# %% [markdown]
# https://www.sfdph.org/dph/EH/Food/score/default.asp

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(1,1,1)
sns.set_style('white')

ax.set_title('SF Sanitation Score Distribution')
ax.set_xlabel('Score', size=24)
ax.set_xlim([20, 100])

sns.kdeplot(rest_data.Score, shade=True, color='#3498db', label='')
ax.axvline(90, color='#7f8c8d')
ax.axvline(86, color='#7f8c8d')
ax.axvline(70, color='#7f8c8d')

#Clean up the chart
sns.despine(left=True, bottom=True)
ax.set_yticklabels([])

ax.tick_params(axis='both', which='major', labelsize=16)
# Out:
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/axes.py:4747: UserWarning: No labeled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labeled objects found. "

# %% [markdown]
# ## The most unsanitary zip codes in SF

# %%
#This command does a group by zip code, then aggregates values, then a sort
rest_data[['postal_code','Score']].groupby('postal_code').aggregate([np.mean, np.min, np.max, len]).sort([('Score','mean')])
#[rest_data.postal_code.isin(zip_code_list)]
# Out:
#                  Score
#                   mean amin amax   len
# postal_code
# 94133        81.415098   46  100  5015
# 94101        81.500000   79   83     8
# 94108        82.636774   47   98  2287
# 94122        82.649606   55   98  2568
# 94609        82.900000   76   98    20
# 94127        83.715044   55   98   664
# 94116        84.485714   54  100   864
# 94513        84.750000   81   96     8
# 94103        84.793595   56   98  3860
# 94102        84.869183   49  100  3099
# 94121        85.033503   55  100  1540
# 94109        85.317139   47   98  3653
# 94143        85.448276   81   96    38
# 94134        85.578378   62   98   580
# 94111        86.118024   62   98  1817
# 94110        86.247501   57  100  4258
# 94124        86.295666   61  100   736
# 94118        86.641221   61   98  1800
# 94123        86.964417   59  100  1753
# 94105        86.967352   63  100   895
# 94120        87.000000   83   98    10
# 94117        87.280702   65   98  1137
# 94115        87.338963   64   98  1846
# 94114        87.386953   58  100  1461
# 94104        87.482650   65   98   703
# 94112        87.854588   64   98  1364
# 94131        87.873563   63  100   382
# 94107        88.067302   67   98  1765
# 94130        89.000000   89   89     5
# 94132        89.021739   60  100   644
# 94158        90.250000   88   94     8
# 94013        96.400000   96   98     5
# 94140        96.500000   96   98     4

# %%
from IPython.display import Image
Image(filename='source_data/sf_zip_codes.jpg')

# %%
zip_to_neighborhood = {'94102':'Hayes Valley/Tenderloin','94103':'South of Market','94107':'Potrero Hill',
                       '94108':'Chinatown', '94109':'Polk/Russian Hill (Nob Hill)', '94110':'Inner Mission/Bernal Heights', '94104': 'Financial District', '94105': 'South Park',
                       '94111':'Embarcadero', '94112':'Ingelside-Excelsior/Crocker-Amazon', '94114':'Castro/Noe Valley', '94115':'Western Addition/Japantown',
                       '94116':'Parkside/Forest Hill', '94117':'Haight-Ashbury', '94118':'Inner Richmond', '94121':'Outer Richmond',
                       '94122':'Sunset', '94123':'Marina', '94124':'Bayview-Hunters Point', '94127':'St. Francis Wood',
                       '94131':'Twin Peaks-Glen Park', '94132':'Lake Merced', '94133':'North Beach/Chinatown', '94134':'Visitacion Valley'}

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(1,1,1)
sns.set_style('whitegrid')

sanitation_scores = []
for zip_code in zip_code_list:
    region = rest_data.postal_code == zip_code
    count = rest_data.postal_code[region].count()
    if count > 100:
        sanitation_scores.append(rest_data.Score[region].values)

sns.boxplot(sanitation_scores, color='#8e44ad', alpha=0.5)
ax.set_ylabel('Score', size=24)
ax.set_xticklabels([zip_to_neighborhood[str(x)] for x in zip_code_list], 
                   fontsize=16, rotation=90)
ax.tick_params(axis='both', which='major', labelsize=16)
ax.set_title('Resturant santiation scores by zip', size=32)
ax.set_ylim([25,101])
print

# %% [markdown]
# ## Make a summary table containing resturants, times inspected and mean score

# %%
#Unpack this
mean_score_data = rest_data[['name','date','Score']].drop_duplicates()
resturant_score = mean_score_data[['name','Score']].groupby('name').aggregate([np.mean, len])
resturant_score.columns = resturant_score.columns.get_level_values(1)
resturant_score.reset_index(inplace=True)
resturant_score.rename(columns={'mean':'mean score', 'len': 'times inspected'}, inplace=True)
resturant_score.tail()
resturant_score.to_csv('test.csv', sep="\t")
#Save this to a csv file

# %%
# !head test.csv
# Out:
# 	name	mean score	times inspected
# 0	 NORDSTROM CAFE BISTRO	84.25	6.0
# 1	100% Dessert Cafe	91.0	3.0
# 2	1058 Hoagie	91.66666666666667	3.0
# 3	123 DELI - Lee's	89.0	1.0
# 4	17th & Noe Market	97.6	5.0
# 5	18 Reasons	95.0	4.0
# 6	18th Street Commissary		2.0
# 7	19th Ave Shell	93.75	5.0
# 8	2001 THAI STICK	90.5	4.0

# %% [markdown]
# ## What were the top 10 worst resturants

# %%
resturant_score.sort('mean score').head(25)
# Out:
#                                 name  mean score  times inspected
# 1518                 Imperial Palace   51.000000                4
# 3695  Yummy Dim Sum & Fast Food, LLC   54.000000                2
# 3419          Tin Vietnamese Cuisine   58.000000                2
# 2259             New Asia Restaurant   59.250000                7
# 2056                      Mangosteen   62.000000                1
# 581                        COVE CAFE   63.666667                5
# 2379                     Osaka Sushi   63.666667                5
# 2600               Punjab Restaurant   64.000000                6
# 3532                 Victor's Bakery   65.000000                4
# 3420                  Tip Top Market   65.000000                3
# 3314                  The Brick Yard   65.000000                4
# 2426                   PICCOLO PETES   65.000000                2
# 1318         Green Papaya Restaurant   66.000000                4
# 1299                 Gourmet Kitchen   66.000000                4
# 1796          LO-COST MEAT MARKET #2   66.000000                2
# 1883            Let's Eat Grill Stop   66.000000                1
# 2455              PUNJAB KABAB HOUSE   66.333333                3
# 1114                      First Cake   66.600000                6
# 1874                Lee's Sandwiches   67.000000                2
# 1750                    LA GALLINITA   67.000000                3
# 311      BROOKLYN PIZZA & RESTAURANT   67.000000                3
# 3571                 Wah Hing Market   67.000000                3
# 1434                Hing Wang Bakery   67.500000                7
# 2004      MING'S FONG LAM RESTAURANT   67.500000                4
# 3546           Viva Pizza Restaurant   67.500000                2

# %%
#Save some lists for later
worst_100 = resturant_score.sort('mean score')['name'][:100]
best_100 = resturant_score.sort('mean score')['name'][-100:]

# %% [markdown]
# ## What were the voilations for the worst resturant?

# %%
rest_data.description[rest_data.name == "Imperial Palace"].value_counts()
# Out:
# Improper thawing methods                                        4
# High risk food holding temperature                              4
# Foods not protected from contamination                          4
# Unclean or degraded floors walls or ceilings                    4
# High risk vermin infestation                                    4
# Unclean or unsanitary food contact surfaces                     3
# Insufficient hot water or running water                         3
# Improper or defective plumbing                                  2
# Improper food storage                                           2
# Improper storage use or identification of toxic substances      2
# Contaminated or adulterated food                                2
# Inadequate and inaccessible handwashing facilities              2
# Unauthorized or unsafe use of time as a public health control measure    1
# Inadequately cleaned or sanitized food contact surfaces         1
# Unapproved or unmaintained equipment or utensils                1
# Improper cooling methods                                        1
# Permit license or inspection report not posted                  1
# Food safety certificate or food handler card not available      1
# Unclean nonfood contact surfaces                                1
# Inadequate dressing rooms or improper storage of personal items    1
# Improper storage of equipment utensils or linens                1
# dtype: int64

# %%
#Search with python string methods inside a column
rest_data[(rest_data.name.isin(worst_100)) & (rest_data.description.str.contains('vermin') > 0)].name.value_counts().head(10)
# Out:
# Lee's Market                         9
# Wasabi Bistro Japanese Restaurant    8
# Ho's Bar & Restaurant Inc            8
# New Chef Hung's Restaurant           8
# New Asia Restaurant                  7
# Whitcomb Hotel Bar & Grill           7
# Chutney USA, Inc.                    6
# Usulutan Restaurant                  6
# First Cake                           6
# Rogue Ales Public House              6
# dtype: int64

# %% [markdown]
# ## Display the data

# %%
#pygamps package is installed in labs/packages
pip install -e packages/pygmaps-0.1.1

# %%
import pygmaps 
from IPython.display import HTML

# %% [markdown]
# ## A closer look at longitude and latitude

# %%
fig = plt.figure(figsize=(20,8))
ax = fig.add_subplot(1,2,1)
sns.kdeplot(rest_data.latitude, shade=True)
ax.set_title('Latitude', size=32)
ax.tick_params(axis='both', which='major', labelsize=16)

ax = fig.add_subplot(1,2,2)
sns.kdeplot(rest_data.longitude, shade=True, vertical=True)
ax.set_title('Longitude', size=32)
ax.tick_params(axis='both', which='major', labelsize=16)

# %% [markdown]
# ### Lets get more realistic boundaries

# %%
latitudes = rest_data.latitude[~np.isnan(rest_data.latitude)]
longitudes = rest_data.longitude[~np.isnan(rest_data.longitude)]

# %%
#Percentile function - takes the value at the given percentile
min_lat, max_lat = np.percentile(latitudes, 1), np.percentile(latitudes, 99)
min_long, max_long = np.percentile(longitudes, 1), np.percentile(longitudes, 99)

# %%
mymap = pygmaps.maps((max_lat + min_lat) / 2, (max_long + min_long) / 2, 13)

#Plot all the worst resturants 
for lat, lon in rest_data[['latitude','longitude']][rest_data.name.isin(worst_100)].drop_duplicates().values:
    mymap.addpoint(lat, lon, '#e74c3c')

#Plot all the best resturants
for lat, lon in rest_data[['latitude','longitude']][rest_data.name.isin(best_100)].drop_duplicates().values:
    mymap.addpoint(lat, lon, '#2ecc71')

mymap.draw('resturant_plot.html')

# %%
HTML('<iframe src=resturant_plot.html width=1000 height=650></iframe>')
# Out:
# <iframe src=resturant_plot.html width=1000 height=650></iframe>

# %%
#Plot vermin
mymap = pygmaps.maps((max_lat + min_lat) / 2, (max_long + min_long) / 2, 13)

for lat, lon in rest_data[['latitude','longitude']][(rest_data.description == "High risk vermin infestation")].drop_duplicates().values:
    mymap.addpoint(lat, lon, '#e74c3c')

mymap.draw('vermin.html')

# %%
HTML('<iframe src=vermin.html width=1000 height=650></iframe>')
# Out:
# <iframe src=vermin.html width=1000 height=650></iframe>
