# %%
import json
import datetime
import numpy as np
import pandas as pd

#pprint - pretty print - preserves formatting
from pprint import pprint

#urllib / requests - used commonly for apis
#import requests
import urllib2

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

from pprint import pprint

# %% [markdown]
# # APIs
# - https://www.yelp.com/developers/documentation
# - http://www.reddit.com/dev/api
# - http://www.publicapis.com
# - https://apps.twitter.com (OAUTH nightmares)
# - http://developer.rottentomatoes.com/docs

# %% [markdown]
# ### Wikipedia

# %% [markdown]
# - https://en.wikipedia.org/w/api.php?action=help&modules=main (API documentation)
# - https://en.wikipedia.org/w/api.php?action=help&modules=query (more documentation)
# - https://en.wikipedia.org/w/api.php?action=help&modules=query%2Bextracts (Returns plain-text or limited HTML extracts of the given pages)

# %%
wiki_base_extracts_url = 'https://en.wikipedia.org/w/api.php?action=query&prop=extracts&format=json&exsentences={num_sent}&titles={nom}'

# %% [markdown]
# ## Using a web api
# - Everything after the '?' is called the query string, '&' denotes variables
# - the '{<variable_name>}' is special python string handling, allowing me to make a more descriptive string
# ### variables used
# - prop: which information I want - in this case - the page extract
# - format: format of the data, json / text / html / etc
# - exsentences: How many sentences of the extract to return
# - There is good documentation of this API in the links above

# %%
def fetch_nominee_json(nom_url):
    #opener class reads the content of urls
    opener = urllib2.build_opener()
    opener.addheaders = [('User-agent', 'Mozilla/5.0')]
    infile = opener.open(nom_url)
    return json.load(infile)

nom_text = fetch_json_from_wiki(wiki_base_extracts_url.format(num_sent=3, nom='Scott_Walker_(politician)'))
print nom_text
# Out:
# {u'query': {u'normalized': [{u'to': u'Scott Walker (politician)', u'from': u'Scott_Walker_(politician)'}], u'pages': {u'1339436': {u'extract': u'<p><b>Scott Kevin Walker</b> (born November 2, 1967) is an American Republican legislator and politician who is the 45th Governor of Wisconsin.</p>', u'ns': 0, u'pageid': 1339436, u'title': u'Scott Walker (politician)'}}}, u'warnings': {u'query': {u'*': u"Formatting of continuation data will be changing soon. To continue using the current formatting, use the 'rawcontinue' parameter. To begin using the new format, pass an empty string for 'continue' in the initial query."}}}

# %% [markdown]
# ## JSON

# %% [markdown]
# - javascript object notation
# - comporable to xml
# - structured information

# %%
pprint(nom_text)
# Out:
# {u'query': {u'normalized': [{u'from': u'Scott_Walker_(politician)',
#                              u'to': u'Scott Walker (politician)'}],
#             u'pages': {u'1339436': {u'extract': u'<p><b>Scott Kevin Walker</b> (born November 2, 1967) is an American Republican legislator and politician who is the 45th Governor of Wisconsin.</p>',
#                                     u'ns': 0,
#                                     u'pageid': 1339436,
#                                     u'title': u'Scott Walker (politician)'}}},
#  u'warnings': {u'query': {u'*': u"Formatting of continuation data will be changing soon. To continue using the current formatting, use the 'rawcontinue' parameter. To begin using the new format, pass an empty string for 'continue' in the initial query."}}}

# %%
nom_text['query']['pages']['1339436']
# Out:
# {u'extract': u'<p><b>Scott Kevin Walker</b> (born November 2, 1967) is an American Republican legislator and politician who is the 45th Governor of Wisconsin.</p>',
#  u'ns': 0,
#  u'pageid': 1339436,
#  u'title': u'Scott Walker (politician)'}

# %%
#Class exercise - get the title of the page and the extract
# Hint dict.keys returns the available keys for a dictionary
#nom_text['query']['pages']['1339436']['title']

# %%
#Incredibly common interview question: Flatten a json object

# %% [markdown]
# ## Wikipedia Page Content

# %%
wiki_content_url = 'https://en.wikipedia.org/w/api.php?action=query&prop=extracts&rvprop=content&format=json&titles={nom}'
GOP_nominees = ['Ted_Cruz', 'Jeb_Bush', 'Scott_Walker_(politician)', 'Marco_Rubio', 'Rand_Paul', 'Rick_Perry', 'Chris_Christie', 'Mike_Huckabee']

nominee_extract = {}
for nominee in GOP_nominees:
    nom_text = fetch_nominee_json(wiki_content_url.format(nom=nominee))
    for page_id in nom_text['query']['pages']:
        nominee_extract[nominee] = nom_text['query']['pages'][page_id]['extract']

# %%
nominee_extract.keys()
# Out:
# ['Mike_Huckabee',
#  'Ted_Cruz',
#  'Rand_Paul',
#  'Chris_Christie',
#  'Scott_Walker_(politician)',
#  'Marco_Rubio',
#  'Jeb_Bush',
#  'Rick_Perry']

# %% [markdown]
# ## Which candidate has the most republican wiki extract?

# %%
from collections import Counter


def fetch_nominee_json(nom_url):
    #opener class reads the content of urls
    opener = urllib2.build_opener()
    opener.addheaders = [('User-agent', 'Mozilla/5.0')]
    infile = opener.open(nom_url)
    return json.loads(infile)

print type(fetch_nominee_json(wiki_base_extracts_url.format(nom=GOP_nominees[0], num_sent=10)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-a24f499c9cd3> in <module>()
#       9     return json.loads(infile)
#      10
# ---> 11 print type(fetch_nominee_json(wiki_base_extracts_url.format(nom=GOP_nominees[0], num_sent=10)))
#
# <ipython-input-54-a24f499c9cd3> in fetch_nominee_json(nom_url)
#       7     opener.addheaders = [('User-agent', 'Mozilla/5.0')]
#       8     infile = opener.open(nom_url)
# ----> 9     return json.loads(infile)
#      10
#      11 print type(fetch_nominee_json(wiki_base_extracts_url.format(nom=GOP_nominees[0], num_sent=10)))
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     336             parse_int is None and parse_float is None and
#     337             parse_constant is None and object_pairs_hook is None and not kw):
# --> 338         return _default_decoder.decode(s)
#     339     if cls is None:
#     340         cls = JSONDecoder
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/decoder.pyc in decode(self, s, _w)
#     363
#     364         """
# --> 365         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     366         end = _w(s, end).end()
#     367         if end != len(s):
#
# TypeError: expected string or buffer

# %% [markdown]
# ## Python set operations

# %%
# https://docs.python.org/2/library/sets.html
ted_cruz_words = set(nominee_extract['Ted_Cruz'].replace(".", "").replace(",", "").lower().split(" "))
rick_perry_words = set(nominee_extract['Rick_Perry'].replace(".", "").replace(",", "").lower().split(" "))

# %%
ted_cruz_words - rick_perry_words

# %%
#Can we clean the corpus more? eliminate common words, deal with puncutation? Perhaps there is a better way :)
#Class exercise, which words are in ted cruz wiki and not any of the other candidates?

# %% [markdown]
# ## Pandas has data sources built in!

# %% [markdown]
# - http://pandas.pydata.org/pandas-docs/stable/remote_data.html

# %%
import datetime
import pandas.io.data as pd_io

# %% [markdown]
# ## Stock Market Data

# %%
start = datetime.datetime(2014, 9, 1)
stop = datetime.datetime(2015, 3, 21)
stock_data = pd_io.DataReader('TSLA', 'yahoo', start, stop)
stock_data.head()
# Out:
#               Open    High     Low   Close    Volume  Adj Close
# Date
# 2014-09-02  275.50  284.89  274.30  284.12   9852400     284.12
# 2014-09-03  287.67  288.00  280.10  281.19   6772300     281.19
# 2014-09-04  284.01  291.42  280.40  286.04   8341700     286.04
# 2014-09-05  282.55  282.90  272.51  277.39  11169900     277.39
# 2014-09-08  277.62  284.88  277.52  282.11   5501600     282.11

# %%
stock_data.Close.plot()

# %% [markdown]
# ## World Bank

# %%
from pandas.io import wb

# %% [markdown]
# - http://nbviewer.ipython.org/github/psychemedia/dataviz4development/blob/master/dataloaders/World%20Bank%20Demo.ipynb
# - http://schoolofdata.org/2014/09/12/easy-access-to-world-bank-and-un-development-data-from-ipython-notebooks/

# %%
wb.search('gdp.*capita.*const')
# Out:
#                       id                                               name  \
# 700   6.0.GDPpc_constant  GDP per capita, PPP (constant 2011 internation...
# 4680             GDPPCKD             GDP per Capita, constant US$, millions
# 6710      NY.GDP.PCAP.KD                 GDP per capita (constant 2005 US$)
# 6712      NY.GDP.PCAP.KN                      GDP per capita (constant LCU)
# 6714   NY.GDP.PCAP.PP.KD  GDP per capita, PPP (constant 2011 internation...
#
#                             source  \
# 700                 LAC Equity Lab
# 4680        GEP Economic Prospects
# 6710  World Development Indicators
# 6712  World Development Indicators
# 6714  World Development Indicators
#
#                                              sourceNote  \
# 700   GDP per capita based on purchasing power parit...
# 4680  GDP per capita is gross domestic product divid...
# 6710  GDP per capita is gross domestic product divid...
# 6712  GDP per capita is gross domestic product divid...
# 6714  GDP per capita based on purchasing power parit...
#
#                                      sourceOrganization            topics
# 700       NULWorld Development Indicators (World Bank)L  Economy & Growth
# 4680  World Bank staff calculations based on World D...  Economy & Growth
# 6710  World Bank national accounts data, and OECD Na...  Economy & Growth
# 6712  World Bank national accounts data, and OECD Na...  Economy & Growth
# 6714  World Bank, International Comparison Program d...  Economy & Growth

# %%
indicators=wb.get_indicators()
indicators
# Out:
#                                    id  \
# 0                  1.0.HCount.1.25usd
# 1                    1.0.HCount.10usd
# 2                   1.0.HCount.2.5usd
# 3                1.0.HCount.Mid10to50
# 4                     1.0.HCount.Ofcl
# 5                 1.0.HCount.Poor4uds
# 6                 1.0.HCount.Vul4to10
# 7                    1.0.PGap.1.25usd
# 8                      1.0.PGap.10usd
# 9                     1.0.PGap.2.5usd
# 10                 1.0.PGap.Mid10to50
# 11                  1.0.PGap.Poor4uds
# 12                  1.0.PGap.Vul4to10
# 13                   1.0.PSev.1.25usd
# 14                     1.0.PSev.10usd
# 15                    1.0.PSev.2.5usd
# 16                 1.0.PSev.Mid10to50
# 17                  1.0.PSev.Poor4uds
# 18                  1.0.PSev.Vul4to10
# 19                 1.1.HCount.1.25usd
# 20                  1.1.HCount.2.5usd
# 21               1.1.HCount.Mid10to50
# 22                    1.1.HCount.Ofcl
# 23                1.1.HCount.Poor4uds
# 24                1.1.HCount.Vul4to10
# 25                   1.1.PGap.1.25usd
# 26                    1.1.PGap.2.5usd
# 27                 1.1.PGap.Mid10to50
# 28                  1.1.PGap.Poor4uds
# 29                  1.1.PGap.Vul4to10
# ...                               ...
# 12505           per_si_ss_p0_preT_tot
# 12506                per_si_ss_p0_rur
# 12507                per_si_ss_p0_tot
# 12508                per_si_ss_p0_urb
# 12509        per_si_ss_p1_ep_preT_tot
# 12510             per_si_ss_p1_ep_tot
# 12511           per_si_ss_p1_preT_tot
# 12512                per_si_ss_p1_rur
# 12513                per_si_ss_p1_tot
# 12514                per_si_ss_p1_urb
# 12515    per_silm.overlap_ep_preT_tot
# 12516         per_silm.overlap_ep_tot
# 12517   per_silm.overlap_pop_preT_tot
# 12518        per_silm.overlap_pop_rur
# 12519        per_silm.overlap_pop_tot
# 12520        per_silm.overlap_pop_urb
# 12521    per_silm.overlap_q1_preT_tot
# 12522         per_silm.overlap_q1_rur
# 12523         per_silm.overlap_q1_tot
# 12524         per_silm.overlap_q1_urb
# 12525   per_sionl.overlap_ep_preT_tot
# 12526        per_sionl.overlap_ep_tot
# 12527  per_sionl.overlap_pop_preT_tot
# 12528       per_sionl.overlap_pop_rur
# 12529       per_sionl.overlap_pop_tot
# 12530       per_sionl.overlap_pop_urb
# 12531   per_sionl.overlap_q1_preT_tot
# 12532        per_sionl.overlap_q1_rur
# 12533        per_sionl.overlap_q1_tot
# 12534        per_sionl.overlap_q1_urb
#
#                                                     name  \
# 0                        Poverty Headcount ($1.25 a day)
# 1               Under Middle Class ($10 a day) Headcount
# 2                        Poverty Headcount ($2.50 a day)
# 3                  Middle Class ($10-50 a day) Headcount
# 4                Official Moderate Poverty Rate-National
# 5                           Poverty Headcount ($4 a day)
# 6                     Vulnerable ($4-10 a day) Headcount
# 7                              Poverty Gap ($1.25 a day)
# 8                     Under Middle Class ($10 a day) Gap
# 9                              Poverty Gap ($2.50 a day)
# 10                       Middle Class ($10-50 a day) Gap
# 11                                Poverty Gap ($4 a day)
# 12                          Vulnerable ($4-10 a day) Gap
# 13                        Poverty Severity ($1.25 a day)
# 14               Under Middle Class ($10 a day) Severity
# 15                        Poverty Severity ($2.50 a day)
# 16                   Middle Class ($10-50 a day)Severity
# 17                           Poverty Severity ($4 a day)
# 18                     Vulnerable ($4-10 a day) Severity
# 19                 Poverty Headcount ($1.25 a day)-Rural
# 20                 Poverty Headcount ($2.50 a day)-Rural
# 21           Middle Class ($10-50 a day) Headcount-Rural
# 22                 Official Moderate Poverty Rate- Rural
# 23                    Poverty Headcount ($4 a day)-Rural
# 24              Vulnerable ($4-10 a day) Headcount-Rural
# 25                       Poverty Gap ($1.25 a day)-Rural
# 26                       Poverty Gap ($2.50 a day)-Rural
# 27                 Middle Class ($10-50 a day) Gap-Rural
# 28                          Poverty Gap ($4 a day)-Rural
# 29                    Vulnerable ($4-10 a day) Gap-Rural
# ...                                                  ...
# 12505  Poverty Headcount reduction (%) -  Other Socia...
# 12506  Poverty Headcount reduction (%) -  Other Socia...
# 12507  Poverty Headcount reduction (%) -  Other Socia...
# 12508  Poverty Headcount reduction (%) -  Other Socia...
# 12509  Poverty Gap reduction (%) -  Other Social Insu...
# 12510  Poverty Gap reduction (%) -  Other Social Insu...
# 12511  Poverty Gap reduction (%) -  Other Social Insu...
# 12512  Poverty Gap reduction (%) -  Other Social Insu...
# 12513  Poverty Gap reduction (%) -  Other Social Insu...
# 12514  Poverty Gap reduction (%) -  Other Social Insu...
# 12515  Population in extreme poor (<$1.25 a day) rece...
# 12516  Population in extreme poor (<$1.25 a day) rece...
# 12517  Population receiving All Social Insurance and ...
# 12518  Population receiving All Social Insurance and ...
# 12519  Population receiving All Social Insurance and ...
# 12520  Population receiving All Social Insurance and ...
# 12521  Population in the poorest quintile receiving A...
# 12522  Population in the poorest quintile receiving A...
# 12523  Population in the poorest quintile receiving A...
# 12524  Population in the poorest quintile receiving A...
# 12525  Population in extreme poor (<$1.25 a day) only...
# 12526  Population in extreme poor (<$1.25 a day) only...
# 12527  Population only receiving All Social Insurance...
# 12528  Population only receiving All Social Insurance...
# 12529  Population only receiving All Social Insurance...
# 12530  Population only receiving All Social Insurance...
# 12531  Population in the poorest quintile only receiv...
# 12532  Population in the poorest quintile only receiv...
# 12533  Population in the poorest quintile only receiv...
# 12534  Population in the poorest quintile only receiv...
#
#                          source  \
# 0                LAC Equity Lab
# 1                LAC Equity Lab
# 2                LAC Equity Lab
# 3                LAC Equity Lab
# 4                LAC Equity Lab
# 5                LAC Equity Lab
# 6                LAC Equity Lab
# 7                LAC Equity Lab
# 8                LAC Equity Lab
# 9                LAC Equity Lab
# 10               LAC Equity Lab
# 11               LAC Equity Lab
# 12               LAC Equity Lab
# 13               LAC Equity Lab
# 14               LAC Equity Lab
# 15               LAC Equity Lab
# 16               LAC Equity Lab
# 17               LAC Equity Lab
# 18               LAC Equity Lab
# 19               LAC Equity Lab
# 20               LAC Equity Lab
# 21               LAC Equity Lab
# 22               LAC Equity Lab
# 23               LAC Equity Lab
# 24               LAC Equity Lab
# 25               LAC Equity Lab
# 26               LAC Equity Lab
# 27               LAC Equity Lab
# 28               LAC Equity Lab
# 29               LAC Equity Lab
# ...                         ...
# 12505  Global Social Protection
# 12506  Global Social Protection
# 12507  Global Social Protection
# 12508  Global Social Protection
# 12509  Global Social Protection
# 12510  Global Social Protection
# 12511  Global Social Protection
# 12512  Global Social Protection
# 12513  Global Social Protection
# 12514  Global Social Protection
# 12515  Global Social Protection
# 12516  Global Social Protection
# 12517  Global Social Protection
# 12518  Global Social Protection
# 12519  Global Social Protection
# 12520  Global Social Protection
# 12521  Global Social Protection
# 12522  Global Social Protection
# 12523  Global Social Protection
# 12524  Global Social Protection
# 12525  Global Social Protection
# 12526  Global Social Protection
# 12527  Global Social Protection
# 12528  Global Social Protection
# 12529  Global Social Protection
# 12530  Global Social Protection
# 12531  Global Social Protection
# 12532  Global Social Protection
# 12533  Global Social Protection
# 12534  Global Social Protection
#
#                                               sourceNote  \
# 0      The poverty headcount index measures the propo...
# 1      The poverty headcount index measures the propo...
# 2      The poverty headcount index measures the propo...
# 3      The poverty headcount index measures the propo...
# 4      The poverty headcount index measures the propo...
# 5      The poverty headcount index measures the propo...
# 6      The poverty headcount index measures the propo...
# 7      The poverty gap captures the mean aggregate in...
# 8      The poverty gap captures the mean aggregate in...
# 9      The poverty gap captures the mean aggregate in...
# 10     The poverty gap captures the mean aggregate in...
# 11     The poverty gap captures the mean aggregate in...
# 12     The poverty gap captures the mean aggregate in...
# 13     The poverty severity index combines informatio...
# 14     The poverty severity index combines informatio...
# 15     The poverty severity index combines informatio...
# 16     The poverty severity index combines informatio...
# 17     The poverty severity index combines informatio...
# 18     The poverty severity index combines informatio...
# 19     The poverty headcount index measures the propo...
# 20     The poverty headcount index measures the propo...
# 21     The poverty headcount index measures the propo...
# 22     The poverty headcount index measures the propo...
# 23     The poverty headcount index measures the propo...
# 24     The poverty headcount index measures the propo...
# 25     The poverty gap captures the mean aggregate in...
# 26     The poverty gap captures the mean aggregate in...
# 27     The poverty gap captures the mean aggregate in...
# 28     The poverty gap captures the mean aggregate in...
# 29     The poverty gap captures the mean aggregate in...
# ...                                                  ...
# 12505                                               NULL
# 12506                                               NULL
# 12507                                               NULL
# 12508                                               NULL
# 12509                                               NULL
# 12510                                               NULL
# 12511                                               NULL
# 12512                                               NULL
# 12513                                               NULL
# 12514                                               NULL
# 12515                                               NULL
# 12516                                               NULL
# 12517                                               NULL
# 12518                                               NULL
# 12519                                               NULL
# 12520                                               NULL
# 12521                                               NULL
# 12522                                               NULL
# 12523                                               NULL
# 12524                                               NULL
# 12525                                               NULL
# 12526                                               NULL
# 12527                                               NULL
# 12528                                               NULL
# 12529                                               NULL
# 12530                                               NULL
# 12531                                               NULL
# 12532                                               NULL
# 12533                                               NULL
# 12534                                               NULL
#
#                                       sourceOrganization  \
# 0      LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 1      LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 2      LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 3      LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 4      LAC Equity Lab tabulations of data from Nation...
# 5      LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 6      LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 7      LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 8      LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 9      LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 10     LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 11     LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 12     LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 13     LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 14     LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 15     LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 16     LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 17     LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 18     LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 19     LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 20     LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 21     LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 22     LAC Equity Lab tabulations of data from Nation...
# 23     LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 24     LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 25     LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 26     LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 27     LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 28     LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 29     LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# ...                                                  ...
# 12505  The Atlas of Social Protection: Indicators of ...
# 12506  The Atlas of Social Protection: Indicators of ...
# 12507  The Atlas of Social Protection: Indicators of ...
# 12508  The Atlas of Social Protection: Indicators of ...
# 12509  The Atlas of Social Protection: Indicators of ...
# 12510  The Atlas of Social Protection: Indicators of ...
# 12511  The Atlas of Social Protection: Indicators of ...
# 12512  The Atlas of Social Protection: Indicators of ...
# 12513  The Atlas of Social Protection: Indicators of ...
# 12514  The Atlas of Social Protection: Indicators of ...
# 12515  The Atlas of Social Protection: Indicators of ...
# 12516  The Atlas of Social Protection: Indicators of ...
# 12517  The Atlas of Social Protection: Indicators of ...
# 12518  The Atlas of Social Protection: Indicators of ...
# 12519  The Atlas of Social Protection: Indicators of ...
# 12520  The Atlas of Social Protection: Indicators of ...
# 12521  The Atlas of Social Protection: Indicators of ...
# 12522  The Atlas of Social Protection: Indicators of ...
# 12523  The Atlas of Social Protection: Indicators of ...
# 12524  The Atlas of Social Protection: Indicators of ...
# 12525  The Atlas of Social Protection: Indicators of ...
# 12526  The Atlas of Social Protection: Indicators of ...
# 12527  The Atlas of Social Protection: Indicators of ...
# 12528  The Atlas of Social Protection: Indicators of ...
# 12529  The Atlas of Social Protection: Indicators of ...
# 12530  The Atlas of Social Protection: Indicators of ...
# 12531  The Atlas of Social Protection: Indicators of ...
# 12532  The Atlas of Social Protection: Indicators of ...
# 12533  The Atlas of Social Protection: Indicators of ...
# 12534  The Atlas of Social Protection: Indicators of ...
#
#                           topics
# 0                       Poverty
# 1                       Poverty
# 2                       Poverty
# 3                       Poverty
# 4                       Poverty
# 5                       Poverty
# 6                       Poverty
# 7                       Poverty
# 8                       Poverty
# 9                       Poverty
# 10                      Poverty
# 11                      Poverty
# 12                      Poverty
# 13                      Poverty
# 14                      Poverty
# 15                      Poverty
# 16                      Poverty
# 17                      Poverty
# 18                      Poverty
# 19                      Poverty
# 20                      Poverty
# 21                      Poverty
# 22                      Poverty
# 23                      Poverty
# 24                      Poverty
# 25                      Poverty
# 26                      Poverty
# 27                      Poverty
# 28                      Poverty
# 29                      Poverty
# ...                          ...
# 12505  Social Protection & Labor
# 12506  Social Protection & Labor
# 12507  Social Protection & Labor
# 12508  Social Protection & Labor
# 12509  Social Protection & Labor
# 12510  Social Protection & Labor
# 12511  Social Protection & Labor
# 12512  Social Protection & Labor
# 12513  Social Protection & Labor
# 12514  Social Protection & Labor
# 12515  Social Protection & Labor
# 12516  Social Protection & Labor
# 12517  Social Protection & Labor
# 12518  Social Protection & Labor
# 12519  Social Protection & Labor
# 12520  Social Protection & Labor
# 12521  Social Protection & Labor
# 12522  Social Protection & Labor
# 12523  Social Protection & Labor
# 12524  Social Protection & Labor
# 12525  Social Protection & Labor
# 12526  Social Protection & Labor
# 12527  Social Protection & Labor
# 12528  Social Protection & Labor
# 12529  Social Protection & Labor
# 12530  Social Protection & Labor
# 12531  Social Protection & Labor
# 12532  Social Protection & Labor
# 12533  Social Protection & Labor
# 12534  Social Protection & Labor
#
# [12535 rows x 6 columns]
